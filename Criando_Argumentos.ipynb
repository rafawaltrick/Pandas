# %% [markdown]
# <a href="https://colab.research.google.com/github/rafawaltrick/Pandas/blob/main/Criando_Argumentos.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
dados = pd.read_csv('/content/drive/MyDrive/Pandas/Pandas_projetos_estudos/dados_residencial.csv', sep=';')

# %%
dados.head(10)
# Out:
#                  Tipo               Bairro  Quartos  Vagas  Suites  Area  \
# 0           Quitinete           Copacabana        1      0       0    40
# 1                Casa      Jardim Botânico        2      0       1   100
# 2         Apartamento               Centro        1      0       0    15
# 3         Apartamento         Higienópolis        1      0       0    48
# 4         Apartamento             Cachambi        2      0       0    50
# 5  Casa de Condomínio      Barra da Tijuca        5      4       5   750
# 6  Casa de Condomínio                Ramos        2      2       0    65
# 7         Apartamento               Grajaú        2      1       0    70
# 8         Apartamento  Lins de Vasconcelos        3      1       1    90
# 9         Apartamento           Copacabana        1      0       1    40
#
#      Valor  Condominio  IPTU  Valor m2 Tipo de Imovel
# 0   1700.0       500.0  60.0     42.50    Apartamento
# 1   7000.0         0.0   0.0     70.00           Casa
# ...

# %% [markdown]
# # Função '.mean( )' para retornar a média da coluna 'Valor'.

# %%
dados['Valor'].mean()
# Out:
# 5046.172821405663

# %% [markdown]
# # Criada a variável 'bairro' apenas com os bairros que eu desejo.
# # Variável 'selecao' para selecionar apenas os bairros da variável 'bairro' dentro da coluna 'Bairro' da DataFrame.
# # Criamos uma DataFrame usando apenas os bairros selecionados na variável 'selecao'.

# %%
bairros = ['Barra da Tijuca', 'Copacabana', 'Ipanema', 'Leblon', 'Botafogo', 'Flamengo', 'Tijuca']
selecao = dados['Bairro'].isin(bairros)
dados = dados[selecao]

# %% [markdown]
# # Retorno dos bairros sem duplicações.

# %%
dados['Bairro'].drop_duplicates()
# Out:
# 0          Copacabana
# 5     Barra da Tijuca
# 15             Tijuca
# 19            Ipanema
# 23           Botafogo
# 27             Leblon
# 78           Flamengo
# Name: Bairro, dtype: object

# %% [markdown]
# # Criando grupos de bairros.

# %%
grupo_bairro = dados.groupby('Bairro')

# %% [markdown]
# # Usar o comando '.groups' para mostar os index de cada bairro.

# %%
grupo_bairro.groups
# Out:
# {'Barra da Tijuca': [5, 14, 16, 21, 30, 32, 35, 42, 43, 60, 61, 64, 68, 74, 79, 93, 107, 110, 112, 117, 130, 132, 136, 150, 153, 155, 165, 166, 173, 186, 189, 207, 214, 221, 224, 233, 236, 239, 244, 259, 265, 274, 276, 291, 292, 293, 295, 302, 308, 311, 325, 335, 336, 345, 360, 366, 368, 374, 380, 387, 389, 400, 412, 432, 433, 435, 436, 439, 449, 451, 462, 463, 465, 473, 476, 484, 494, 500, 503, 511, 537, 538, 539, 540, 543, 547, 552, 554, 555, 556, 584, 587, 588, 590, 594, 596, 601, 611, 622, 630, ...], 'Botafogo': [23, 48, 87, 88, 111, 119, 127, 134, 196, 200, 225, 334, 362, 415, 416, 498, 524, 526, 545, 593, 649, 685, 719, 756, 765, 822, 827, 861, 915, 924, 928, 1006, 1043, 1080, 1091, 1110, 1116, 1127, 1140, 1165, 1201, 1205, 1223, 1250, 1282, 1295, 1304, 1317, 1348, 1383, 1414, 1419, 1455, 1517, 1529, 1579, 1630, 1655, 1670, 1699, 1741, 1742, 1788, 1814, 1823, 1826, 1853, 1922, 1931, 1957, 1972, 1981, 1989, 2029, 2066, 2069, 2081, 2083, 2084, 2088, 2097, 2148, 2149, 2165, 2179, 
# ...

# %% [markdown]
# # Criando um laço para ver os dados do 'grupo_bairro'.
# # Para as variáveis 'bairro' e 'dados' dentro do grupo 'grupo_bairro', o retorno será os nomes dos bairros e a média dos valores contidos na coluna 'Valor'.

# %%
for bairro, dados in grupo_bairro:
  print('{} -> {}'.format(bairro, dados.Valor.mean()))
# Out:
# Barra da Tijuca -> 7069.552938130986
# Botafogo -> 8791.828178694159
# Copacabana -> 4126.677004538578
# Flamengo -> 4113.526610644258
# Ipanema -> 9352.001133786847
# Leblon -> 8746.344992050874
# Tijuca -> 2043.52

# %% [markdown]
# # Ou podemos pegar a variável 'grupo_bairro', escolher a coluna a ser retornada calculando a média com o comando '.mean( )' e arredondando para 2 casas decimais com o comando '.round(2)'.

# %%
grupo_bairro[['Valor', 'Condominio']].mean().round(2)
# Out:
#                    Valor  Condominio
# Bairro
# Barra da Tijuca  7069.55     3591.01
# Botafogo         8791.83      976.28
# Copacabana       4126.68     1148.68
# Flamengo         4113.53     1102.15
# Ipanema          9352.00     2244.44
# Leblon           8746.34     2107.18
# Tijuca           2043.52      711.69

# %% [markdown]
# # Exercício

# %%
import pandas as pd
alunos = pd.DataFrame({'Nome': ['Ary', 'Cátia', 'Denis', 'Beto', 'Bruna', 'Dara', 'Carlos', 'Alice'], 
                        'Sexo': ['M', 'F', 'M', 'M', 'F', 'F', 'M', 'F'], 
                        'Idade': [15, 27, 56, 32, 42, 21, 19, 35], 
                        'Notas': [7.5, 2.5, 5.0, 10, 8.2, 7, 6, 5.6], 
                        'Aprovado': [True, False, False, True, True, True, False, False]}, 
                        columns = ['Nome', 'Idade', 'Sexo', 'Notas', 'Aprovado'])

# %%
alunos
# Out:
#      Nome  Idade Sexo  Notas  Aprovado
# 0     Ary     15    M    7.5      True
# 1   Cátia     27    F    2.5     False
# 2   Denis     56    M    5.0     False
# 3    Beto     32    M   10.0      True
# 4   Bruna     42    F    8.2      True
# 5    Dara     21    F    7.0      True
# 6  Carlos     19    M    6.0     False
# 7   Alice     35    F    5.6     False

# %% [markdown]
# ## Como devemos proceder para obter um DataFrame com as notas médias dos alunos, com duas casas decimais, segundo seu sexo?

# %%
# Primeiro foi criado grupos da coluna 'Sexo' usando o comando '.groupby( )'.
sexo = alunos.groupby('Sexo')

# %%
# Foi criada uma DataFrame como a variável 'sexo', criada a cima, usando a coluna 'Notas' e tirando a média dessas notas com o comando '.mean()' e arredondando pra 2 casas decimais com o comando '.round(2'.)
sexo = pd.DataFrame(sexo['Notas'].mean().round(2))

# %%
# Foi criada mais uma coluna com o comando '.columns' para a DataFrame.
sexo.columns = ['Notas Médias']

# %%
sexo
# Out:
#       Notas Médias
# Sexo
# F             5.82
# M             7.12

# %% [markdown]
# # Estatísticas Descritivas

# %%
grupo_bairro['Valor'].describe().round(2)
# Out:
#                   count     mean        std     min     25%     50%      75%  \
# Bairro
# Barra da Tijuca  3863.0  7069.55   11874.15   800.0  2500.0  4500.0   8500.0
# Botafogo          873.0  8791.83  152202.41   700.0  2200.0  3000.0   4350.0
# Copacabana       2644.0  4126.68    3611.41   100.0  2000.0  3000.0   4800.0
# Flamengo          714.0  4113.53    3839.13   800.0  1900.0  2900.0   4975.0
# Ipanema          1764.0  9352.00    8219.72  1200.0  4500.0  7000.0  11000.0
# Leblon           1258.0  8746.34    7004.04   100.0  4500.0  7000.0  10500.0
# Tijuca           1100.0  2043.52    1664.34   750.0  1500.0  1800.0   2300.0
#
#                        max
# Bairro
# Barra da Tijuca   600000.0
# Botafogo         4500000.0
# Copacabana         35000.0
# Flamengo           35000.0
# Ipanema            90000.0
# Leblon            100000.0
# Tijuca             45000.0

# %% [markdown]
# # Na variável 'grupo_bairro', na coluna 'Valor', posso agregar com a função '.aggregate( ) valores mínimos e máximos além de renomear esses novos valores com a função '.rename( )'.

# %%
grupo_bairro['Valor'].aggregate(['min', 'max'])
# Out:
#                     min        max
# Bairro
# Barra da Tijuca   800.0   600000.0
# Botafogo          700.0  4500000.0
# Copacabana        100.0    35000.0
# Flamengo          800.0    35000.0
# Ipanema          1200.0    90000.0
# Leblon            100.0   100000.0
# Tijuca            750.0    45000.0

# %%
grupo_bairro['Valor'].aggregate(['min', 'max']).rename(columns = {'min': 'Mínimo', 'max': 'Máximo'})
# Out:
#                  Mínimo     Máximo
# Bairro
# Barra da Tijuca   800.0   600000.0
# Botafogo          700.0  4500000.0
# Copacabana        100.0    35000.0
# Flamengo          800.0    35000.0
# Ipanema          1200.0    90000.0
# Leblon            100.0   100000.0
# Tijuca            750.0    45000.0

# %% [markdown]
# # O comando '%matplotlib' permite que seja visualizado gráficos.
# # matplotlib.pyplot é uma ferramenta para geração de graficos no Python.
# # 'plt.rc( )' é um comando para configurar os gráficos, nesse caso o tamanho do mesmo.

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.rc('figure', figsize = (20, 10))

# %% [markdown]
# # Foi criado o gráfico do desvio padrão (.std( )) em barras (.plot.bar( )) na cor vermelha (color = 'red') sem bordas (plt.box(False)) e quadriculado (plt.grid(True))
# # Podemos fazer vários tipos de dados nesse grafico mundando a função '.std( )' para o que desejar. Ex.: '.mean( )', '.max( )' média e máximo respectivamente.

# %%
grupo_bairro['Valor'].std().plot.bar(color = 'red')
plt.box(False)
plt.grid(True)

# %%
grupo_bairro['Valor'].max().plot.bar(color = 'red')
plt.box(False)
plt.grid(True)

# %% [markdown]
# # Podem ser atribuidos títulos e legandas.

# %%
grupo_bairro['Valor'].max().plot.bar(color = 'red')
plt.box(False)
plt.grid(True)
plt.title('Tabela de Valores Máximos')
plt.legend()
plt.xlabel('Bairros')
plt.ylabel('Valor Aluguel')
# Out:
# Text(0, 0.5, 'Valor Aluguel')

# %% [markdown]
# # Exercício

# %%
precos = pd.DataFrame([['Feira', 'Cebola', 2.5], 
                        ['Mercado', 'Cebola', 1.99], 
                        ['Supermercado', 'Cebola', 1.69], 
                        ['Feira', 'Tomate', 4], 
                        ['Mercado', 'Tomate', 3.29], 
                        ['Supermercado', 'Tomate', 2.99], 
                        ['Feira', 'Batata', 4.2], 
                        ['Mercado', 'Batata', 3.99], 
                        ['Supermercado', 'Batata', 3.69]], 
                        columns = ['Local', 'Produto', 'Preço'])
precos
# Out:
#           Local Produto  Preço
# 0         Feira  Cebola   2.50
# 1       Mercado  Cebola   1.99
# 2  Supermercado  Cebola   1.69
# 3         Feira  Tomate   4.00
# 4       Mercado  Tomate   3.29
# 5  Supermercado  Tomate   2.99
# 6         Feira  Batata   4.20
# 7       Mercado  Batata   3.99
# 8  Supermercado  Batata   3.69

# %%
produtos = precos.groupby('Produto', sort = False)
produtos.describe().round(2)
# Out:
#         Preço
#         count  mean   std   min   25%   50%   75%  max
# Produto
# Cebola    3.0  2.06  0.41  1.69  1.84  1.99  2.24  2.5
# Tomate    3.0  3.43  0.52  2.99  3.14  3.29  3.64  4.0
# Batata    3.0  3.96  0.26  3.69  3.84  3.99  4.10  4.2

# %% [markdown]
# ## Utilizando o DataFrame (precos) acima, que código seria necessário para gerar uma tabela com 'Média, Desvio Padrão, Mínimo e Máximo dos produtos'?

# %%
produtos['Preço'].aggregate(['mean', 'std', 'min', 'max']).rename(columns = {'mean': 'Média', 'std': 'Desvio Padrão', 'min': 'Mínimo', 'max': 'Máximo'}).round(2)
# Out:
#          Média  Desvio Padrão  Mínimo  Máximo
# Produto
# Cebola    2.06           0.41    1.69     2.5
# Tomate    3.43           0.52    2.99     4.0
# Batata    3.96           0.26    3.69     4.2

# %%
estatisticas = ['mean', 'std', 'min', 'max']
nomes = {'mean': 'Média', 'std': 'Desvio Padrão', 'min': 'Mínimo', 'max': 'Máximo'}
produtos['Preço'].aggregate(estatisticas).rename(columns = nomes).round(2)
# Out:
#          Média  Desvio Padrão  Mínimo  Máximo
# Produto
# Cebola    2.06           0.41    1.69     2.5
# Tomate    3.43           0.52    2.99     4.0
# Batata    3.96           0.26    3.69     4.2
