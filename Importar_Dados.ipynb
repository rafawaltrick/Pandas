# %% [markdown]
# <a href="https://colab.research.google.com/github/rafawaltrick/Pandas/blob/main/Importar_Dados.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Importando Dados

# %%
import pandas as pd

# %% [markdown]
# # Comando para visualizar um arquivo 'json' em Python

# %%
json = open('/content/drive/MyDrive/Pandas/Pandas_projetos_estudos/extras/dados/aluguel.json')
print(json.read())
# Out:
# [{"Tipo":"Quitinete","Bairro":"Copacabana","Quartos":1,"Vagas":0,"Suites":0,"Area":40,"Valor":1700.0,"Condominio":500.0,"IPTU":60.0},
# {"Tipo":"Casa","Bairro":"Jardim Bot\u00e2nico","Quartos":2,"Vagas":0,"Suites":1,"Area":100,"Valor":7000.0,"Condominio":null,"IPTU":null},
# {"Tipo":"Conjunto Comercial\/Sala","Bairro":"Barra da Tijuca","Quartos":0,"Vagas":4,"Suites":0,"Area":150,"Valor":5200.0,"Condominio":4020.0,"IPTU":1111.0},
# {"Tipo":"Apartamento","Bairro":"Centro","Quartos":1,"Vagas":0,"Suites":0,"Area":15,"Valor":800.0,"Condominio":390.0,"IPTU":20.0},
# {"Tipo":"Apartamento","Bairro":"Higien\u00f3polis","Quartos":1,"Vagas":0,"Suites":0,"Area":48,"Valor":800.0,"Condominio":230.0,"IPTU":null},
# {"Tipo":"Apartamento","Bairro":"Vista Alegre","Quartos":3,"Vagas":1,"Suites":0,"Area":70,"Valor":1200.0,"Condominio":null,"IPTU":null},
# {"Tipo":"Apartamento","Bairro":"Cachambi","Quartos":2,"Vagas":0,"Suites":0,"Area":50,"Valor":1300.0,"Condominio":301.0,"IPTU":17.0},
# ...

# %% [markdown]
# # Comando para vizualizar 'json' no Pandas.

# %%
df_json = pd.read_json('/content/drive/MyDrive/Pandas/Pandas_projetos_estudos/extras/dados/aluguel.json')
df_json
# Out:
#                       Tipo           Bairro  Quartos  Vagas  Suites  Area  \
# 0                Quitinete       Copacabana        1      0       0    40
# 1                     Casa  Jardim Botânico        2      0       1   100
# 2  Conjunto Comercial/Sala  Barra da Tijuca        0      4       0   150
# 3              Apartamento           Centro        1      0       0    15
# 4              Apartamento     Higienópolis        1      0       0    48
# 5              Apartamento     Vista Alegre        3      1       0    70
# 6              Apartamento         Cachambi        2      0       0    50
# 7       Casa de Condomínio  Barra da Tijuca        5      4       5   750
# 8       Casa de Condomínio            Ramos        2      2       0    65
# 9  Conjunto Comercial/Sala           Centro        0      3       0   695
#
#    Valor  Condominio    IPTU
# 0   1700       500.0    60.0
# 1   7000         NaN     NaN
# 2   5200      4020.0  1111.0
# 3    800       390.0    20.0
# ...

# %% [markdown]
# # Visualizar um arquivo 'txt' em Python

# %%
txt = open('/content/drive/MyDrive/Pandas/Pandas_projetos_estudos/extras/dados/aluguel.txt')
print(txt.read())
# Out:
# Tipo	Bairro	Quartos	Vagas	Suites	Area	Valor	Condominio	IPTU
# Quitinete	Copacabana	1	0	0	40	1700	500	60
# Casa	Jardim Botânico	2	0	1	100	7000
# Conjunto Comercial/Sala	Barra da Tijuca	0	4	0	150	5200	4020	1111
# Apartamento	Centro	1	0	0	15	800	390	20
# Apartamento	Higienópolis	1	0	0	48	800	230
# Apartamento	Vista Alegre	3	1	0	70	1200
# Apartamento	Cachambi	2	0	0	50	1300	301	17
# Casa de Condomínio	Barra da Tijuca	5	4	5	750	22000
# Casa de Condomínio	Ramos	2	2	0	65	1000
# Conjunto Comercial/Sala	Centro	0	3	0	695	35000	19193	3030

# %% [markdown]
# # Comando para vizualizar 'txt' no Pandas.

# %%
df_txt = pd.read_table('/content/drive/MyDrive/Pandas/Pandas_projetos_estudos/extras/dados/aluguel.txt')
df_txt
# Out:
#                       Tipo           Bairro  Quartos  Vagas  Suites  Area  \
# 0                Quitinete       Copacabana        1      0       0    40
# 1                     Casa  Jardim Botânico        2      0       1   100
# 2  Conjunto Comercial/Sala  Barra da Tijuca        0      4       0   150
# 3              Apartamento           Centro        1      0       0    15
# 4              Apartamento     Higienópolis        1      0       0    48
# 5              Apartamento     Vista Alegre        3      1       0    70
# 6              Apartamento         Cachambi        2      0       0    50
# 7       Casa de Condomínio  Barra da Tijuca        5      4       5   750
# 8       Casa de Condomínio            Ramos        2      2       0    65
# 9  Conjunto Comercial/Sala           Centro        0      3       0   695
#
#    Valor  Condominio    IPTU
# 0   1700       500.0    60.0
# 1   7000         NaN     NaN
# 2   5200      4020.0  1111.0
# 3    800       390.0    20.0
# ...

# %% [markdown]
# # Comando para vizualizar 'xlsx' no Pandas.

# %%
df_xlsx = pd.read_excel('/content/drive/MyDrive/Pandas/Pandas_projetos_estudos/extras/dados/aluguel.xlsx')
df_xlsx
# Out:
#                       Tipo           Bairro  Quartos  Vagas  Suites  Area  \
# 0                Quitinete       Copacabana        1      0       0    40
# 1                     Casa  Jardim Botânico        2      0       1   100
# 2  Conjunto Comercial/Sala  Barra da Tijuca        0      4       0   150
# 3              Apartamento           Centro        1      0       0    15
# 4              Apartamento     Higienópolis        1      0       0    48
# 5              Apartamento     Vista Alegre        3      1       0    70
# 6              Apartamento         Cachambi        2      0       0    50
# 7       Casa de Condomínio  Barra da Tijuca        5      4       5   750
# 8       Casa de Condomínio            Ramos        2      2       0    65
# 9  Conjunto Comercial/Sala           Centro        0      3       0   695
#
#    Valor  Condominio    IPTU
# 0   1700       500.0    60.0
# 1   7000         NaN     NaN
# 2   5200      4020.0  1111.0
# 3    800       390.0    20.0
# ...

# %% [markdown]
# # Vizualizar tabela de um arquivo 'HTML' em Pandas. O conteúdo vem em uma lista [ ].

# %%
df_html = pd.read_html('/content/drive/MyDrive/Pandas/Pandas_projetos_estudos/extras/dados/dados_html_1.html')
df_html
# Out:
# [  FAIXA ETÁRIA UNAFISCO SAÚDE SOFT II SOFT PARTICIPATIVO      UNIQUE
#  0      00 A 18               R$218,99           R$192,60    R$334,48
#  1      19 A 23               R$263,63           R$207,67    R$380,06
#  2      24 A 28               R$322,44           R$224,26    R$464,39
#  3      29 A 33               R$402,05           R$258,63    R$566,68
#  4      34 A 38               R$455,17           R$306,37    R$664,61
#  5      39 A 43               R$489,29           R$417,93    R$742,72
#  6      44 A 48               R$582,65           R$495,24    R$869,47
#  7      49 A 53               R$718,86           R$562,64  R$1.046,29
#  8      54 A 58               R$908,54           R$721,00  R$1.355,74
#  9   59 OU MAIS             R$1.244,50         R$1.151,62  R$2.003,53]

# %% [markdown]
# # Para visualizar o conteúdo 'HTML' em  uma DataFrame, basta mostrar o conteúdo da lista com [0].

# %%
df_html = pd.read_html('/content/drive/MyDrive/Pandas/Pandas_projetos_estudos/extras/dados/dados_html_1.html')
df_html[0]
# Out:
#   FAIXA ETÁRIA UNAFISCO SAÚDE SOFT II SOFT PARTICIPATIVO      UNIQUE
# 0      00 A 18               R$218,99           R$192,60    R$334,48
# 1      19 A 23               R$263,63           R$207,67    R$380,06
# 2      24 A 28               R$322,44           R$224,26    R$464,39
# 3      29 A 33               R$402,05           R$258,63    R$566,68
# 4      34 A 38               R$455,17           R$306,37    R$664,61
# 5      39 A 43               R$489,29           R$417,93    R$742,72
# 6      44 A 48               R$582,65           R$495,24    R$869,47
# 7      49 A 53               R$718,86           R$562,64  R$1.046,29
# 8      54 A 58               R$908,54           R$721,00  R$1.355,74
# 9   59 OU MAIS             R$1.244,50         R$1.151,62  R$2.003,53

# %% [markdown]
# # A visualização pode ser feita direto pelo link onde se encontra uma tabela.

# %%
df_html = pd.read_html('https://unafiscosaude.org.br/site/comparativo-de-planos/')
df_html
# Out:
# [              NOME COMERCIAL PLANO >>  \
#  0                        Registro ANS
#  1               Situação do Plano ANS
#  2                 Tipo de Contratação
#  3            Segmentação Assistencial
#  4                         Odontologia
#  5                  Formação do preço:
#  6            Vínculo do Beneficiário:
#  7                Padrão de acomodação
#  8                      Coparticipação
#  9          Cobertura de procedimentos
#  10  Serviços e coberturas adicionais:
#  11                     Livre Escolha:
#  12               Rede de atendimento:
#
#                                                SOFT II  \
#  0                                       Nº. 471839149
#  1                                               Ativo
#  2                                 Coletivo por adesão
#  3          "Ambulatorial + Hospitalar com Obstetrícia
#  4                                              Não há
#  5                                     Preestabelecido
# ...

# %% [markdown]
# # E como no exemplo anterior, o retorno é de uma lista[ ]. E para visualizar no formato DataFrame, de o comando de visualizar conteúdo da lista [0].

# %%
df_html = pd.read_html('https://unafiscosaude.org.br/site/comparativo-de-planos/')
df_html[0]
# Out:
#               NOME COMERCIAL PLANO >>  \
# 0                        Registro ANS
# 1               Situação do Plano ANS
# 2                 Tipo de Contratação
# 3            Segmentação Assistencial
# 4                         Odontologia
# 5                  Formação do preço:
# 6            Vínculo do Beneficiário:
# 7                Padrão de acomodação
# 8                      Coparticipação
# 9          Cobertura de procedimentos
# 10  Serviços e coberturas adicionais:
# 11                     Livre Escolha:
# 12               Rede de atendimento:
#
#                                               SOFT II  \
# 0                                       Nº. 471839149
# 1                                               Ativo
# 2                                 Coletivo por adesão
# 3          "Ambulatorial + Hospitalar com Obstetrícia
# 4                                              Não há
# 5                                     Preestabelecido
# ...

# %% [markdown]
# # Quando o site tiver mais de uma tabela?

# %% [markdown]
# # Ao tentar ler as tabelas com 'pd.read_html' e ter como retorno um HTTP Error 403, isso se deve pois o método read_html lê apenas aplicações mais simples, então provavelmente ocorreu uma alteração no site e o método do pandas não consegue mais coletar as informações da página facilmente. Desse modo, para fazer a leitura de tabelas de site mais complexos será necessário realizar um Web Scraping.

# %% [markdown]
# # É necessário ter instaladas as bibliotecas requests e BeautifulSoup no ambiente python. Para instalá-las, basta executar os códigos nas células do notebook: '!pip install requests' e '!pip install bs4'.

# %%
# !pip install requests
# !pip install bs4
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %% [markdown]
# # Aqui importamos as bibliotecas instaladas.

# %%
import requests
from bs4 import BeautifulSoup

# %% [markdown]
# # Para retonar a lista de tabelas, é nescessário executar esses comandos.

# %%
url='https://www.federalreserve.gov/releases/h3/current/default.htm'
response = requests.get(url)
html = response.content
soup = BeautifulSoup(html, 'html.parser')
table = soup.findAll('table')
html_file = f'<html><body>{table}</body></html>'

# %% [markdown]
# # Como a função read_html retorna uma lista de DataFrames, basta acessar as tabelas pelos índices da lista.
# # Como temos três tabelas na página usamos os índices [0], [1] ou [2] para acessar os DataFrames que buscamos

# %%
df = pd.read_html(html_file)

# %%
df[0]
# Out:
#                   Date      Reserve balances required  \
#                   Date Reserve balance requirements 1
# 0              Month 7                        Month 7
# 1            Aug. 2019                         134639
# 2           Sept. 2019                         134707
# 3            Oct. 2019                         134998
# 4            Nov. 2019                         140705
# 5            Dec. 2019                         138984
# 6            Jan. 2020                         144816
# 7            Feb. 2020                         138370
# 8            Mar. 2020                         113139
# 9            Apr. 2020                              0
# 10            May 2020                              0
# 11           June 2020                              0
# 12           July 2020                              0
# 13           Aug. 2020                              0
# 14                 NaN                            NaN
# ...

# %%
df[1]
# Out:
#                   Date            Reserves                      \
#                   Date             Total 1            Required
# 0              Month 7             Month 7             Month 7
# 1            Aug. 2019             1586844              200608
# 2           Sept. 2019             1504805              199741
# 3            Oct. 2019             1547136              200621
# 4            Nov. 2019             1595222              206586
# 5            Dec. 2019             1698344              207239
# 6            Jan. 2020             1715219              214652
# 7            Feb. 2020             1726943              208324
# 8            Mar. 2020             2099369              167360
# 9            Apr. 2020             2953586                   0
# 10            May 2020             3217635                   0
# 11           June 2020             3043556                   0
# 12           July 2020             2718529                   0
# ...

# %%
df[2]
# Out:
#                   Date Borrowings from the Federal Reserve  \
#                   Date                               Total
# 0              Month 3                             Month 3
# 1            Aug. 2019                                 117
# 2           Sept. 2019                                 101
# 3            Oct. 2019                                  63
# 4            Nov. 2019                                  26
# 5            Dec. 2019                                  21
# 6            Jan. 2020                                   6
# 7            Feb. 2020                                   3
# 8            Mar. 2020                               40554
# 9            Apr. 2020                              124461
# 10            May 2020                              111845
# 11           June 2020                               97671
# 12           July 2020                               92943
# 13           Aug. 2020                               83126
# ...
